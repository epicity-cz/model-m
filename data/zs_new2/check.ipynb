# %%
import pandas as pd

# %%
df = pd.read_csv("nodes_groups.csv")

# %%
df
# Out:
#        id  sex  age class  Atletika  Basketbal  Bricks 4 kidz  \
# 0       1  NaN   55   NaN       NaN        NaN            NaN
# 1       2  NaN   65   NaN       NaN        NaN            NaN
# 2       3  NaN   25   NaN       NaN        NaN            NaN
# 3       4  NaN   45   NaN       NaN        NaN            NaN
# 4       5  NaN   55   NaN       NaN        NaN            NaN
# ..    ...  ...  ...   ...       ...        ...            ...
# 674  1626  NaN    7    2C       NaN        NaN            NaN
# 675  1627  NaN    7    2B       0.0        0.0            0.0
# 676  1628  NaN    7    2A       0.0        0.0            0.0
# 677  1629  NaN    7    2C       1.0        0.0            0.0
# 678  1630  NaN    7    2C       NaN        NaN            NaN
#
#      Dílnička pro holky  Florbal  Fotbal  ...  \
# 0                   NaN      NaN     NaN  ...
# 1                   NaN      NaN     NaN  ...
# 2                   NaN      NaN     NaN  ...
# ...
